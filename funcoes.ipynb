# %% [markdown]
# # Funções para recomendações

# %%
from math import sqrt

# Dataframe fictício para testes simples
from recomendacoes import *

# Dataframe real fornecido pelo MovieLens
def df_movie_lens(path='ml-100k'):
    # Inicializa dicionário de filmes
    filmes = {}
    for linha in open(path + '/u.item', encoding='latin-1'):
        campos = linha.split('|')
        id_filme, titulo = campos[0], campos[1]
        filmes[id_filme] = titulo

    base = {}
    # Percorre os usuários e armazena no dicionário
    for linha in open(path + '/u.data', encoding='latin-1'):
        usuario, id_filme, nota, tempo = linha.split('\t')
        base.setdefault(usuario, {})
        base[usuario][id_filme] = float(nota)

    return base, filmes

base_movie_lens, filmes = df_movie_lens('ml-100k')

def recomenda_itens(base_usuario, similaridade_itens, usuario, id_para_titulo):
    notasUsuario = base_usuario[usuario]
    notas = {}
    totalSimilaridade = {}

    for (item, nota) in notasUsuario.items():
        for (similaridade, item2) in similaridade_itens[item]:
            if item2 in notasUsuario:
                continue
            notas.setdefault(item2, 0)
            notas[item2] += similaridade * nota
            totalSimilaridade.setdefault(item2, 0)
            totalSimilaridade[item2] += similaridade

    rankings = [(score / totalSimilaridade[item], id_para_titulo[item]) for item, score in notas.items()]
    rankings.sort()
    rankings.reverse()

    # Adicione instruções de impressão para depuração
    print(f"Notas: {notas}")
    print(f"Total de Similaridade: {totalSimilaridade}")

    return rankings


def euclidiana(base, usuario1, usuario2):
    si = {item: 1 for item in base[usuario1] if item in base[usuario2]}

    if len(si) == 0:
        return 0  # Nenhuma similaridade se não houver itens em comum

    soma = sum([pow(base[usuario1][item] - base[usuario2][item], 2) for item in si])
    return 1 / (1 + sqrt(soma))


def users_similares(base, usuario):
    similaridade = [(euclidiana(base, usuario, outro), outro) for outro in base if outro != usuario]
    similaridade.sort()
    similaridade.reverse()
    return similaridade[0:10]

def recomenda_users(base, usuario):
    totais = {}
    somaSimilaridade = {}

    for outro in base:
        if outro == usuario:
            continue
        similaridade = euclidiana(base, usuario, outro)

        if similaridade <= 0:
            continue

        for item in base[outro]:
            if item not in base[usuario]:
                totais.setdefault(item, 0)
                totais[item] += base[outro][item] * similaridade
                somaSimilaridade.setdefault(item, 0)
                somaSimilaridade[item] += similaridade

    rankings = [(total / somaSimilaridade[item], item) for item, total in totais.items()]
    rankings.sort()
    rankings.reverse()
    return rankings[0:30]

def calcula_itens_similares(base):
    result = {}
    for item in base:
        notas = users_similares(base, item)
        result[item] = notas
    return result


def recomenda_itens(base, similaridade_itens, usuario, id_para_titulo):
    notasUsuario = base[usuario]
    notas = {}
    totalSimilaridade = {}

    for (item, nota) in notasUsuario.items():
        for (similaridade, item2) in similaridade_itens[item]:
            if item2 in notasUsuario:
                continue
            notas.setdefault(item2, 0)
            notas[item2] += similaridade * nota
            totalSimilaridade.setdefault(item2, 0)
            totalSimilaridade[item2] += similaridade

    rankings = [(score / totalSimilaridade[item], id_para_titulo[item]) for item, score in notas.items()]
    rankings.sort()
    rankings.reverse()

    # Adicione instruções de impressão para depuração
    print(f"Notas: {notas}")
    print(f"Total de Similaridade: {totalSimilaridade}")

    return rankings

def recomenda_itens_ficticio(base, similaridade_itens, usuario):
    notasUsuario = base[usuario]
    notas = {}
    totalSimilaridade = {}

    for (item, nota) in notasUsuario.items():
        for (similaridade, item2) in similaridade_itens[item]:
            if item2 in notasUsuario:
                continue
            notas.setdefault(item2, 0)
            notas[item2] += similaridade * nota
            totalSimilaridade.setdefault(item2, 0)
            totalSimilaridade[item2] += similaridade

    rankings = [(score / totalSimilaridade[item]) for item, score in notas.items()]
    rankings.sort()
    rankings.reverse()

    # Adicione instruções de impressão para depuração
    print(f"Notas: {notas}")
    print(f"Total de Similaridade: {totalSimilaridade}")

    return rankings

# %% [markdown]
# # Testes
#
# ### Base de dados fictícia

# %%
recomenda_users(avaliacoes_usuarios, 'Leonardo')
# Out:
# [(3.457128694491423, 'Star Wars'),
#  (2.778584003814924, 'Freddy x Jason'),
#  (2.422482042361917, 'Star Trek')]

# %%
itens_similares = calcula_itens_similares(avaliacoes_filmes)

print(itens_similares)
# Out:
# {'Freddy x Jason': [(0.4721359549995794, 'Norbit'), (0.3761785115301142, 'Star Wars'), (0.3567891723253309, 'O Ultimato Bourne'), (0.3483314773547883, 'Star Trek'), (0.2402530733520421, 'Exterminador do Futuro')], 'O Ultimato Bourne': [(0.3761785115301142, 'Exterminador do Futuro'), (0.3567891723253309, 'Freddy x Jason'), (0.3266316347104093, 'Star Wars'), (0.32037724101704074, 'Star Trek'), (0.1886378647726465, 'Norbit')], 'Star Trek': [(0.3761785115301142, 'Norbit'), (0.3483314773547883, 'Freddy x Jason'), (0.32037724101704074, 'O Ultimato Bourne'), (0.2708131845707603, 'Star Wars'), (0.20799159651347807, 'Exterminador do Futuro')], 'Exterminador do Futuro': [(0.3761785115301142, 'O Ultimato Bourne'), (0.27429188517743175, 'Star Wars'), (0.2402530733520421, 'Freddy x Jason'), (0.20799159651347807, 'Star Trek'), (0.18464218557642828, 'Norbit')], 'Norbit': [(0.4721359549995794, 'Freddy x Jason'), (0.3761785115301142, 'Star Trek'), (0.29429805508554946, 'Star Wars'), (0.1886378647726465, 'O Ultimato Bourne'), (0.18464218557642828, 'Exterminador do Futuro')], 'Star Wars': [(0.3761785115301142, 'Freddy x Jason'), (0.3266316347104093, 'O Ultimato Bourne'), (0.29429805508554946, 'Norbit'), (0.27429188517743175, 'Exterminador do Futuro'), (0.2708131845707603, 'Star Trek')]}

# %%
recomenda_itens_ficticio(avaliacoes_usuarios, itens_similares, 'Leonardo')
# Out:
# Notas: {'Freddy x Jason': 3.0386995238717365, 'Star Wars': 2.861307951992118, 'Star Trek': 2.6498424821607096}
# Total de Similaridade: {'Freddy x Jason': 1.0691782006769524, 'Star Wars': 0.8952215749733905, 'Star Trek': 0.904547349060633}
# [3.1962008423190285, 2.929467965289551, 2.8420889258196413]

# %% [markdown]
# # Testes
# ## Base de dados MovieLens

# %%
# Exemplo 1: Encontrar usuários similares a um usuário específico
usuario_exemplo1 = '1'
usuarios_similares_exemplo1 = users_similares(base_movie_lens, usuario_exemplo1)
print(f"Usuários similares ao usuário {usuario_exemplo1}:")
for similaridade, outro_usuario in usuarios_similares_exemplo1:
    print(f"Usuário {outro_usuario} - Similaridade: {similaridade}")
# Out:
# Usuários similares ao usuário 1:
# Usuário 812 - Similaridade: 1.0
# Usuário 418 - Similaridade: 1.0
# Usuário 155 - Similaridade: 1.0
# Usuário 729 - Similaridade: 0.5
# Usuário 631 - Similaridade: 0.5
# Usuário 351 - Similaridade: 0.5
# Usuário 309 - Similaridade: 0.5
# Usuário 273 - Similaridade: 0.5
# Usuário 876 - Similaridade: 0.4142135623730951
# Usuário 485 - Similaridade: 0.4142135623730951

# %%
# Exemplo 2: Fornecer recomendações de filmes para um usuário específico
usuario_exemplo2 = '1'
recomendacoes_exemplo2 = recomenda_users(base_movie_lens, usuario_exemplo2)
print(f"Recomendações de filmes para o usuário {usuario_exemplo2}:")
for pontuacao, filme in recomendacoes_exemplo2:
    print(f"Filme: {filme} - Pontuação: {pontuacao}")
# Out:
# Recomendações de filmes para o usuário 1:
# Filme: 1467 - Pontuação: 5.000000000000001
# Filme: 1189 - Pontuação: 5.000000000000001
# Filme: 814 - Pontuação: 5.0
# Filme: 1653 - Pontuação: 5.0
# Filme: 1599 - Pontuação: 5.0
# Filme: 1536 - Pontuação: 5.0
# Filme: 1500 - Pontuação: 5.0
# Filme: 1201 - Pontuação: 5.0
# Filme: 1122 - Pontuação: 5.0
# Filme: 1293 - Pontuação: 4.999999999999999
# Filme: 1449 - Pontuação: 4.709540786352371
# Filme: 1642 - Pontuação: 4.624759150439772
# Filme: 1398 - Pontuação: 4.605117943969987
# Filme: 1191 - Pontuação: 4.551685512163036
# Filme: 408 - Pontuação: 4.512901471394128
# Filme: 318 - Pontuação: 4.503322988079016
# Filme: 483 - Pontuação: 4.474105171116072
# Filme: 513 - Pontuação: 4.448398214360137
# Filme: 1367 - Pontuação: 4.4388914364740515
# Filme: 1594 - Pontuação: 4.4121968395559765
# Filme: 603 - Pontuação: 4.403246514259
# Filme: 1639 - Pontuação: 4.365085124965483
# Filme: 285 - Pontuação: 4.332368408305184
# Filme: 1396 - Pontuação: 4.331407117669634
# Filme: 480 - Pontuação: 4.326677679611185
# Filme: 357 - Pontuação: 4.316866195618117
# Filme: 427 - Pontuação: 4.3108163582413335
# Filme: 1524 - Pontuação: 4.304034713117433
# Filme: 511 - Pontuação: 4.303751338413961
# Filme: 657 - Pontuação: 4.285009368538586

# %%
# Exemplo 3: Calcular itens similares e fornecer recomendações de itens para um usuário
itens_similares = calcula_itens_similares(base_movie_lens)
usuario_exemplo3 = '1'
recomendacoes_itens_exemplo3 = recomenda_itens(base_movie_lens, itens_similares, usuario_exemplo3, filmes)
print(f"Recomendações de itens para o usuário {usuario_exemplo3}:")
for pontuacao, item in recomendacoes_itens_exemplo3:
    print(f"Item: {item} - Pontuação: {pontuacao}")
# Out:
# Notas: {'939': 81.0, '891': 34.0, '852': 23.65685424949238, '815': 28.0, '766': 34.5, '705': 5.0, '812': 46.0, '431': 18.598076211353316, '888': 59.79674482879475, '866': 43.5, '811': 57.985281374238575, '935': 36.5, '903': 13.0, '901': 24.0, '892': 10.0, '861': 38.41421356237309, '859': 39.32842712474619, '814': 53.572767706041475, '798': 15.0, '767': 67.98698126841458, '856': 65.0, '813': 60.5, '784': 31.5, '720': 52.15685424949238, '688': 70.57106781186548, '628': 18.869693845669907, '410': 17.0, '302': 20.55492646310117, '905': 20.5, '787': 25.0, '755': 24.0, '702': 17.0, '681': 21.0, '662': 18.413719988157784, '448': 27.0, '915': 43.0, '923': 13.0, '917': 48.0, '872': 14.0, '789': 29.5, '714': 10.0, '644': 5.0, '595': 9.0, '941': 57.098076211353316, '922': 22.0, '900': 29.0, '868': 28.0, '759': 5.0, '726': 36.66914402321879, '723': 17.89564392373896, '716': 20.0, '558': 45.96796292722099, '522': 59.480375165651424, '473': 12.0, '366': 16.045084971874736, '358': 16.0, '934': 2.0, '916': 7.0, '893': 13.0, '869': 36.5, '769': 34.333333333333336, '763': 7.0, '876': 78.23238054684293, '791': 26.0, '656': 15.097167540709727, '565': 75.3955111598244, '427': 38.61114344745585, '857': 67.32352091615905, '810': 31.5, '895': 64.69281600149327, '865': 28.0, '844': 12.0, '835': 4.0, '341': 74.49645229395796, '732': 52.15685424949238, '824': 34.50918658701249, '775': 69.16361198446985, '631': 28.652417506703802, '855': 78.49030874060482, '845': 63.878203601230744, '675': 25.5, '584': 28.5, '477': 17.0, '306': 5.0, '874': 17.369693845669907, '873': 50.5, '918': 31.5, '822': 52.37867041900558, '700': 41.0, '607': 23.5, '585': 24.427050983124843, '508': 14.0, '319': 61.5, '312': 5.0, '713': 37.277810114122516, '670': 33.0, '571': 51.822436584232555, '553': 12.0, '826': 13.0, '776': 30.0, '600': 48.0, '568': 16.098076211353316, '310': 4.0, '289': 16.0, '511': 32.884776310850235, '359': 1.6568542494923804, '816': 55.96410161513775, '609': 7.464101615137754, '369': 40.363596551749424, '367': 6.464101615137754, '651': 21.0, '364': 11.5, '685': 10.49981868916632, '353': 20.242640687119284, '309': 24.904401145198808, '906': 18.0, '793': 17.0, '756': 5.0, '740': 27.5, '718': 14.0, '909': 84.98698126841458, '762': 62.41421356237309, '737': 15.0, '736': 21.18486083519388, '730': 4.0, '803': 58.0, '750': 41.0, '519': 32.071067811865476, '938': 20.0, '914': 61.606343992275555, '783': 39.0, '853': 26.571067811865476, '832': 17.0, '827': 34.0, '817': 6.0, '792': 14.242640687119286, '712': 21.414213562373096, '691': 36.0, '658': 6.0, '536': 6.0, '426': 17.0, '908': 24.0, '849': 69.5, '840': 14.0, '821': 29.0, '715': 21.0, '809': 31.899494936611664, '797': 17.0, '794': 26.0, '469': 36.21204412261039, '912': 41.366025403784434, '765': 22.65685424949238, '692': 9.0, '321': 2.0, '273': 21.5, '728': 26.2876225312968, '701': 2.5, '696': 57.0, '611': 36.071067811865476, '375': 37.37563667661529, '355': 31.823520916159048, '924': 3.0, '842': 64.73205080756888, '819': 26.5, '520': 17.0, '659': 3.0, '890': 15.0, '879': 42.5, '878': 6.0, '613': 15.644313430378721, '415': 17.57979589711327, '799': 19.0, '420': 2.5, '384': 23.692130429902463, '808': 41.833333333333336, '936': 8.0, '904': 25.0, '898': 17.0, '863': 27.0, '858': 28.598076211353316, '770': 4.0, '725': 17.0, '677': 14.0, '786': 5.0, '719': 9.0, '680': 10.0, '643': 7.0, '562': 4.0, '928': 32.0, '884': 25.0, '925': 41.06125539469119, '920': 41.53516942700323, '722': 18.0, '687': 28.0, '400': 16.0, '841': 61.0, '801': 47.5, '754': 20.3407168984726, '462': 1.098076211353316, '570': 10.0, '317': 26.476225044541614, '729': 29.0, '485': 24.007305382002812, '444': 6.045084971874737, '481': 0.36602540378443865, '744': 15.65685424949238, '583': 13.914213562373096, '573': 4.0, '434': 5.242640687119286, '411': 8.0, '563': 7.464101615137754, '926': 22.0, '574': 8.0, '414': 8.0, '820': 23.5, '440': 14.0, '377': 13.0, '668': 10.0, '695': 19.0, '589': 6.0, '578': 13.73606797749979, '590': 15.0, '386': 7.0, '911': 14.0, ...
# Total de Similaridade: {'939': 20.5, '891': 12.0, '852': 6.414213562373095, '815': 6.0, '766': 10.0, '705': 2.0, '812': 11.5, '431': 4.866025403784439, '888': 18.098914942931582, '866': 12.5, '811': 16.32842712474619, '935': 10.5, '903': 5.0, '901': 8.0, '892': 4.0, '861': 11.914213562373096, '859': 13.914213562373096, '814': 16.280238966157533, '798': 4.0, '767': 20.113572299490865, '856': 16.5, '813': 17.0, '784': 9.0, '720': 14.414213562373096, '688': 17.74754689570643, '628': 5.289897948556636, '410': 4.0, '302': 5.64031728896187, '905': 4.5, '787': 7.0, '755': 6.0, '702': 5.0, '681': 5.0, '662': 4.682743997631556, '448': 6.0, '915': 11.5, '923': 4.0, '917': 14.5, '872': 3.0, '789': 7.5, '714': 2.0, '644': 1.0, '595': 2.0, '941': 13.36602540378444, '922': 5.0, '900': 7.0, '868': 9.0, '759': 1.0, '726': 10.280238966157533, '723': 4.179128784747792, '716': 5.0, '558': 13.97780467396644, '522': 16.661760458079527, '473': 5.0, '366': 4.3090169943749475, '358': 4.5, '934': 1.0, '916': 2.0, '893': 4.0, '869': 11.5, '769': 11.833333333333332, '763': 2.0, '876': 23.82637509669092, '791': 7.0, '656': 4.274291885177432, '565': 20.565384140902207, '427': 11.027785861863963, '857': 20.747546895706428, '810': 8.5, '895': 15.038563200298652, '865': 7.0, '844': 3.0, '835': 1.0, '341': 20.951367322083225, '732': 12.914213562373096, '824': 8.484059392534334, '775': 20.283708489063113, '631': 8.836443858371492, '855': 22.163530306684905, '845': 17.384991014827566, '675': 7.0, '584': 8.0, '477': 5.0, '306': 1.0, '874': 5.789897948556636, '873': 11.5, '918': 8.0, '822': 16.175734083801117, '700': 11.0, '607': 5.5, '585': 5.8090169943749475, '508': 3.0, '319': 15.0, '312': 1.0, '713': 10.694452528530629, '670': 11.0, '571': 12.704111510929732, '553': 3.0, '826': 4.0, '776': 10.0, '600': 11.333333333333334, '568': 4.366025403784439, '310': 1.0, '289': 3.5, '511': 8.742640687119284, '359': 0.4142135623730951, '816': 16.366025403784437, '609': 2.3660254037844384, '369': 11.194452528530629, '367': 1.3660254037844386, '651': 6.0, '364': 3.5, '685': 3.589255960532481, '353': 5.414213562373095, '309': 7.661760458079523, '906': 6.0, '793': 4.0, '756': 1.0, '740': 6.5, '718': 4.5, '909': 23.280238966157533, '762': 17.914213562373096, '737': 5.0, '736': 6.106278477136481, '730': 2.0, '803': 16.0, '750': 11.5, '519': 8.414213562373096, '938': 5.0, '914': 17.49400945948637, '783': 11.5, '853': 6.914213562373095, '832': 6.0, '827': 10.0, '817': 2.0, '792': 4.414213562373095, '712': 6.414213562373095, '691': 9.0, '658': 2.0, '536': 2.0, '426': 5.0, '908': 8.0, '849': 18.5, '840': 5.0, '821': 7.0, '715': 6.0, '809': 8.828427124746192, '797': 4.0, '794': 7.0, '469': 9.806983955628535, '912': 12.86602540378444, '765': 7.414213562373095, '692': 3.5, '321': 0.5, '273': 6.0, '728': 8.613572299490865, '701': 0.5, '696': 15.0, '611': 8.414213562373096, '375': 9.253889588452738, '355': 7.747546895706428, '924': 1.0, '842': 17.366025403784437, '819': 6.0, '520': 4.0, '659': 2.0, '890': 6.0, '879': 15.0, '878': 2.0, '613': 4.4070932057282635, '415': 4.289897948556636, '799': 7.0, '420': 0.5, '384': 6.704111510929731, '808': 11.833333333333334, '936': 2.0, '904': 8.0, '898': 5.5, '863': 9.0, '858': 8.36602540378444, '770': 1.0, '725': 5.0, '677': 3.0, '786': 2.0, '719': 2.0, '680': 3.0, '643': 2.0, '562': 1.0, '928': 9.0, '884': 8.0, '925': 11.495093791412858, '920': 10.780238966157535, '722': 5.0, '687': 7.5, '400': 4.0, '841': 18.0, '801': 11.5, '754': 5.780238966157533, '462': 0.36602540378443865, '570': 3.0, '317': 6.793895945414847, '729': 8.0, '485': 6.398272954907429, '444': 1.8090169943749475, '481': 0.36602540378443865, '744': 4.414213562373095, '583': 3.914213562373095, '573': 1.0, '434': 1.4142135623730951, '411': 2.0, '563': 2.3660254037844384, '926': 6.0, '574': 3.0, '414': 2.0, '820': 6.5, '440': 4.0, '377': 3.0, '668': 2.0, '695': 5.0, '589': 2.0, '578': 5.8090169943749475, '590': 4.0, '386': 1.5, '911': 5.0, '780': 4.5, '777': 1.0, '850': 3.0, '837': 4. ...
# Recomendações de itens para o usuário 1:
# Item: Wonderful, Horrible Life of Leni Riefenstahl, The (1993) - Pontuação: 5.0
# Item: To Gillian on Her 37th Birthday (1996) - Pontuação: 5.0
# Item: Tin Drum, The (Blechtrommel, Die) (1979) - Pontuação: 5.0
# Item: Threesome (1994) - Pontuação: 5.0
# Item: Thin Blue Line, The (1988) - Pontuação: 5.0
# Item: Serial Mom (1994) - Pontuação: 5.0
# Item: Rob Roy (1995) - Pontuação: 5.0
# Item: Picnic (1955) - Pontuação: 5.0
# Item: Night of the Living Dead (1968) - Pontuação: 5.0
# Item: My Left Foot (1989) - Pontuação: 5.0
# Item: Murder, My Sweet (1944) - Pontuação: 5.0
# Item: Mrs. Brown (Her Majesty, Mrs. Brown) (1997) - Pontuação: 5.0
# Item: Midnight in the Garden of Good and Evil (1997) - Pontuação: 5.0
# Item: Menace II Society (1993) - Pontuação: 5.0
# Item: Magnificent Seven, The (1954) - Pontuação: 5.0
# Item: Little Odessa (1994) - Pontuação: 5.0
# Item: Island of Dr. Moreau, The (1996) - Pontuação: 5.0
# Item: In the Line of Duty 2 (1987) - Pontuação: 5.0
# Item: Hunchback of Notre Dame, The (1996) - Pontuação: 5.0
# Item: Father of the Bride Part II (1995) - Pontuação: 5.0
# Item: Farewell My Concubine (1993) - Pontuação: 5.0
# Item: Fair Game (1995) - Pontuação: 5.0
# Item: Die Hard: With a Vengeance (1995) - Pontuação: 5.0
# Item: Close Shave, A (1995) - Pontuação: 5.0
# Item: Carrington (1995) - Pontuação: 5.0
# Item: Blood Beach (1981) - Pontuação: 5.0
# Item: Bio-Dome (1996) - Pontuação: 5.0
# Item: Big Lebowski, The (1998) - Pontuação: 5.0
# Item: Believers, The (1987) - Pontuação: 5.0
# Item: Audrey Rose (1977) - Pontuação: 5.0
# Item: Amityville: A New Generation (1993) - Pontuação: 5.0
# Item: American in Paris, An (1951) - Pontuação: 5.0
# Item: Alice in Wonderland (1951) - Pontuação: 5.0
# Item: River Wild, The (1994) - Pontuação: 4.75
# Item: Clueless (1995) - Pontuação: 4.732050807568878
# Item: People vs. Larry Flynt, The (1996) - Pontuação: 4.666666666666667
# Item: One Fine Day (1996) - Pontuação: 4.666666666666667
# Item: Love Jones (1997) - Pontuação: 4.666666666666667
# Item: Fire on the Mountain (1996) - Pontuação: 4.666666666666667
# Item: Addams Family Values (1993) - Pontuação: 4.666666666666667
# Item: Once Upon a Time in the West (1969) - Pontuação: 4.659648368883419
# Item: Evita (1996) - Pontuação: 4.571428571428571
# Item: Great Expectations (1998) - Pontuação: 4.555555555555555
# Item: Trainspotting (1996) - Pontuação: 4.5
# Item: Sophie's Choice (1982) - Pontuação: 4.5
# Item: Ransom (1996) - Pontuação: 4.5
# Item: Omen, The (1976) - Pontuação: 4.5
# Item: Mulholland Falls (1996) - Pontuação: 4.5
# Item: Meet John Doe (1941) - Pontuação: 4.5
# Item: In the Line of Fire (1993) - Pontuação: 4.5
# Item: Game, The (1997) - Pontuação: 4.5
# Item: Flower of My Secret, The (Flor de mi secreto, La) (1995) - Pontuação: 4.5
# Item: Fan, The (1996) - Pontuação: 4.5
# Item: Emma (1996) - Pontuação: 4.5
# Item: Canadian Bacon (1994) - Pontuação: 4.5
# Item: Eddie (1996) - Pontuação: 4.416666666666667
# Item: Dead Man (1995) - Pontuação: 4.4
# Item: Picture Perfect (1997) - Pontuação: 4.391304347826087
# Item: Replacement Killers, The (1998) - Pontuação: 4.333333333333333
# Item: Prophecy II, The (1998) - Pontuação: 4.333333333333333
# Item: Heavyweights (1994) - Pontuação: 4.333333333333333
# Item: Scream 2 (1997) - Pontuação: 4.3017950012810084
# Item: Laura (1944) - Pontuação: 4.286920880302948
# Item: Cape Fear (1962) - Pontuação: 4.285714285714286
# Item: Boys on the Side (1995) - Pontuação: 4.282147032427227
# Item: Rebecca (1940) - Pontuação: 4.2727272727272725
# Item: With Honors (1994) - Pontuação: 4.271881467110383
# Item: Timecop (1994) - Pontuação: 4.25
# Item: Phantoms (1998) - Pontuação: 4.25
# Item: Kingpin (1996) - Pontuação: 4.25
# Item: Great Escape, The (1963) - Pontuação: 4.25
# Item: Crooklyn (1994) - Pontuação: 4.25
# Item: Daniel Defoe's Robinson Crusoe (1996) - Pontuação: 4.235294117647059
# Item: Jane Eyre (1996) - Pontuação: 4.230769230769231
# Item: Son in Law (1993) - Pontuação: 4.20502315740827
# Item: Wishmaster (1997) - Pontuação: 4.2
# Item: Ninotchka (1939) - Pontuação: 4.2
# Item: Hard Rain (1998) - Pontuação: 4.176470588235294
# Item: Young Poisoner's Handbook, The (1995) - Pontuação: 4.166666666666667
# Item: Kalifornia (1993) - Pontuação: 4.146446609406726
# Item: Mrs. Winterbourne (1996) - Pontuação: 4.142857142857143
# Item: Kundun (1997) - Pontuação: 4.142857142857143
# Item: How to Be a Player (1997) - Pontuação: 4.142857142857143
# Item: Air Up There, The (1994) - Pontuação: 4.130434782608695
# Item: Sphere (1998) - Pontuação: 4.107560927936449
# Item: Everyone Says I Love You (1996) - Pontuação: 4.1
# Item: Apple Dumpling Gang, The (1975) - Pontuação: 4.097952004435935
# Item: Another Stakeout (1993) - Pontuação: 4.079186217756995
# Item: Great White Hype, The (1996) - Pontuação: 4.067532414657461
# Item: Showgirls (1995) - Pontuação: 4.038911024317131
# Item: Dave (1993) - Pontuação: 4.038717030470736
# Item: Washington Square (1997) - Pontuação: 4.0
# Item: Walk in the Clouds, A (1995) - Pontuação: 4.0
# Item: Very Brady Sequel, A (1996) - Pontuação: 4.0
# Item: Time to Kill, A (1996) - Pontuação: 4.0
# Item: Smile Like Yours, A (1997) - Pontuação: 4.0
# Item: Shaggy Dog, The (1959) - Pontuação: 4.0
# Item: Rear Window (1954) - Pontuação: 4.0
# Item: Rainmaker, The (1997) - Pontuação: 4.0
# Item: Quick and the Dead, The (1995) - Pontuação: 4.0
# Item: Only You (1994) - Pontuação: 4.0
# Item: Nutty Professor, The (1996) - Pontuação: 4.0
# Item: My Favorite Year (1982) - Pontuação: 4.0
# Item: Mother (1996) - Pontuação: 4.0
# Item: Mission: Impossible (1996) - Pontuação: 4.0
# Item: Miller's Crossing (1990) - Pontuação: 4.0
# Item: Mary Poppins (1964) - Pontuação: 4.0
# Item: Little Rascals, The (1994) - Pontuação: 4.0
# Item: Killing Fields, The (1984) - Pontuação: 4.0
# Item: Juror, The (1996) - Pontuação: 4.0
# Item: Jumanji (1995) - Pontuação: 4.0
# Item: Jingle All the Way (1996) - Pontuação: 4.0
# Item: Interview with the Vampire (1994) - Pontuação: 4.0
# Item: Ice Storm, The (1997) - Pontuação: 4.0
# Item: House of the Spirits, The (1993) - Pontuação: 4.0
# Item: Home for the Holidays (1995) - Pontuação: 4.0
# Item: Heathers (1989) - Pontuação: 4.0
# Item: Harold and Maude (1971) - Pontuação: 4.0
# Item: Giant (1956) - Pontuação: 4.0
# Item: Gay Divorcee, The (1934) - Pontuação: 4.0
# Item: Freeway (1996) - Pontuação: 4.0
# Item: Fled (1996) - Pontuação: 4.0
# Item: Devil in a Blue Dress (1995) - Pontuação: 4.0
# Item: Dark City (1998) - Pontuação: 4.0
# Item: Cook the Thief His Wife & Her Lover, The (1989) - Pontuação: 4.0
# Item: Clear and Present Danger (1994) - Pontuação: 4.0
# Item: Cat People (1982) - Pontuação: 4.0
# Item: Burnt Offerings (1976) - Pontuação: 4.0
# Item: Bridges of Madison County, The (1995) - Pontuação: 4.0
# Item: Bride of Frankenstein (1935) - Pontuação: 4.0
# Item: Brassed Off (1996) - Pontuação: 4.0
# Item: Body Snatchers (1993) - Pontuação: 4.0
# Item: Blues Brothers 2000 (1998) - Pontuação: 4.0
# Item: Birds, The (1963) - Pontuação: 4.0
# Item: Big Squeeze, The (1996) - Pontuação: 4.0
# Item: Bad Moon (1996) - Pontuação: 4.0
# Item: Assignment, The (1997) - Pontuação: 4.0
# Item: Andre (1994) - Pontuação: 4.0
# Item: Air Force One (1997) - Pontuação: 4.0
# Item: Leave It to Beaver (1997) - Pontuação: 3.9763843547830464
# Item: Murder in the First (1995) - Pontuação: 3.951219512195122
# Item: Night on Earth (1991) - Pontuação: 3.9393939393939394
# Item: City of Angels (1998) - Pontuação: 3.9375
# Item: Swimming with Sharks (1995) - Pontuação: 3.933333333333333
# Item: Somewhere in Time (1980) - Pontuação: 3.932249979386252
# Item: In the Name of the Father (1993) - Pontuação: 3.8970607229288277
# Item: Perfect World, A (1993) - Pontuação: 3.875
# Item: Two Bits (1995) - Pontuação: 3.8528987675871402
# Item: Braindead (1992) - Pontuação: 3.842963132707425
# Item: Local Hero (1983) - Pontuação: 3.8284271247461903
# Item: Highlander (1986) - Pontuação: 3.822026123597524
# Item: Treasure of the Sierra Madre, The (1948) - Pontuação: 3.8115348005049134
# Item: Kicking and Screaming (1995) - Pontuação: 3.8
# Item: City Hall (1996) - Pontuação: 3.8
# Item: Paths of Glory (1957) - Pontuação: 3.7887885053796073
# Item: Girl 6 (1996) - Pontuação: 3.7852627661454066
# Item: Dumb & Dumber (1994) - Pontuação: 3.7777777777777777
# Item: Lawrence of Arabia (1962) - Pontuação: 3.7614237491539675
# Item: Days of Thunder (1990) - Pontuação: 3.7567567567567566
# Item: My Fair Lady (1964) - Pontuação: 3.7521539876771564
# Item: Shine (1996) - Pontuação: 3.75
# Item: Hellraiser: Bloodline (1996) - Pontuação: 3.75
# Item: Bad Company (1995) - Pontuação: 3.75
# Item: Primary Colors (1998) - Pontuação: 3.739130434782609
# Item: Deep Rising (1998) - Pontuação: 3.7387961250362585
# Item: It Happened One Night (1934) - Pontuação: 3.736842105263158
# Item: McHale's Navy (1997) - Pontuação: 3.7333333333333334
# Item: Pollyanna (1960) - Pontuação: 3.727511005106692
# Item: Miami Rhapsody (1995) - Pontuação: 3.727272727272727
# Item: Dangerous Minds (1995) - Pontuação: 3.7236067977499787
# Item: It Could Happen to You (1994) - Pontuação: 3.7142857142857144
# Item: Baby-Sitters Club, The (1995) - Pontuação: 3.7142857142857144
# Item: Forbidden Planet (1956) - Pontuação: 3.7071067811865475
# Item: Shadow, The (1994) - Pontuação: 3.7058823529411766
# Item: Cinderella (1950) - Pontuação: 3.7
# Item: Short Cuts (1993) - Pontuação: 3.692475106154035
# Item: Bloody Child, The (1996) - Pontuação: 3.688192483684617
# Item: Speed (1994) - Pontuação: 3.687123807708407
# Item: That Thing You Do! (1996) - Pontuação: 3.674330550228606
# Item: Thousand Acres, A (1997) - Pontuação: 3.6666666666666665
# Item: Escape from New York (1981) - Pontuação: 3.6666666666666665
# Item: Down Periscope (1996) - Pontuação: 3.6666666666666665
# Item: Village of the Damned (1995) - Pontuação: 3.666136778348395
# Item: Dangerous Beauty (1998) - Pontuação: 3.650606052281512
# Item: L.A. Confidential (1997) - Pontuação: 3.644285491407951
# Item: Nosferatu (Nosferatu, eine Symphonie des Grauens) (1922) - Pontuação: 3.642857142857143
# Item: Nell (1994) - Pontuação: 3.625
# Item: Heaven & Earth (1993) - Pontuação: 3.625
# Item: First Knight (1995) - Pontuação: 3.618432183191928
# Item: Space Jam (1996) - Pontuação: 3.6153846153846154
# Item: Rising Sun (1993) - Pontuação: 3.6132704598304923
# Item: Black Sheep (1996) - Pontuação: 3.6056784776993025
# Item: Nine Months (1995) - Pontuação: 3.6
# Item: Heat (1995) - Pontuação: 3.5833333333333335
# Item: Unforgettable (1996) - Pontuação: 3.5720678873768774
# Item: Roommates (1995) - Pontuação: 3.5714285714285716
# Item: Down by Law (1986) - Pontuação: 3.5698733825457523
# Item: Sleepers (1996) - Pontuação: 3.56711869097939
# Item: Fluke (1995) - Pontuação: 3.566954439865973
# Item: Amistad (1997) - Pontuação: 3.5652173913043477
# Item: Secret Garden, The (1993) - Pontuação: 3.5625
# Item: Celluloid Closet, The (1995) - Pontuação: 3.5588235294117645
# Item: Critical Care (1997) - Pontuação: 3.555684512076545
# Item: Spawn (1997) - Pontuação: 3.5555555555555554
# Item: Craft, The (1996) - Pontuação: 3.5555555555555554
# Item: Romeo Is Bleeding (1993) - Pontuação: 3.554791617945659
# Item: Thirty-Two Short Films About Glenn Gould (1993) - Pontuação: 3.551185973470785
# Item: My Man Godfrey (1936) - Pontuação: 3.5498031695913563
# Item: Michael Collins (1996) - Pontuação: 3.546918160678027
# Item: Diva (1981) - Pontuação: 3.5414172586454233
# Item: Program, The (1993) - Pontuação: 3.535211267605634
# Item: Naked Gun 33 1/3: The Final Insult (1994) - Pontuação: 3.533970219808713
# Item: M (1931) - Pontuação: 3.532086237035968
# Item: Wild Things (1998) - Pontuação: 3.521568005033212
# Item: Red Corner (1997) - Pontuação: 3.519009684126308
# Item: To Kill a Mockingbird (1962) - Pontuação: 3.501259811453179
# Item: Winter Guest, The (1997) - Pontuação: 3.5
# Item: To Die For (1995) - Pontuação: 3.5
# Item: The Innocent (1994) - Pontuação: 3.5
# Item: My Fellow Americans (1996) - Pontuação: 3.5
# Item: Made in America (1993) - Pontuação: 3.5
# Item: Lost in Space (1998) - Pontuação: 3.5
# Item: Kids (1995) - Pontuação: 3.5
# Item: Happy Gilmore (1996) - Pontuação: 3.5
# Item: Glory (1989) - Pontuação: 3.5
# Item: Beyond Bedlam (1993) - Pontuação: 3.5
# Item: Amityville II: The Possession (1982) - Pontuação: 3.5
# Item: Othello (1995) - Pontuação: 3.485714674470047
# Item: Beautiful Girls (1996) - Pontuação: 3.484061041533385
# Item: Michael (1996) - Pontuação: 3.48
# Item: Paradise Road (1997) - Pontuação: 3.4761904761904763
# Item: Shadowlands (1993) - Pontuação: 3.469357140280384
# Item: Man of the Year (1995) - Pontuação: 3.45
# Item: Candyman: Farewell to the Flesh (1995) - Pontuação: 3.419529191381846
# Item: Amityville: Dollhouse (1996) - Pontuação: 3.4183587583199
# Item: Wings of Desire (1987) - Pontuação: 3.417545430295163
# Item: Something to Talk About (1995) - Pontuação: 3.409810983122863
# Item: Transformers: The Movie, The (1986) - Pontuação: 3.4
# Item: Richie Rich (1994) - Pontuação: 3.4
# Item: Matilda (1996) - Pontuação: 3.4
# Item: Exit to Eden (1994) - Pontuação: 3.4
# Item: Daylight (1996) - Pontuação: 3.4
# Item: Barcelona (1994) - Pontuação: 3.4
# Item: Milk Money (1994) - Pontuação: 3.391304347826087
# Item: Glimmer Man, The (1996) - Pontuação: 3.388888888888889
# Item: Addiction, The (1995) - Pontuação: 3.380154467644494
# Item: Blob, The (1958) - Pontuação: 3.341640786499874
# Item: Tin Men (1987) - Pontuação: 3.338556372365373
# Item: Wyatt Earp (1994) - Pontuação: 3.3333333333333335
# Item: Time Tracers (1995) - Pontuação: 3.3333333333333335
# Item: Swiss Family Robinson (1960) - Pontuação: 3.3333333333333335
# Item: So Dear to My Heart (1949) - Pontuação: 3.3333333333333335
# Item: Kull the Conqueror (1997) - Pontuação: 3.3333333333333335
# Item: Circle of Friends (1995) - Pontuação: 3.3333333333333335
# Item: Mercury Rising (1998) - Pontuação: 3.310344827586207
# Item: One Night Stand (1997) - Pontuação: 3.3038856206210303
# Item: Great Day in Harlem, A (1994) - Pontuação: 3.2906622450324963
# Item: Heavenly Creatures (1994) - Pontuação: 3.2886396683476327
# Item: Ace Ventura: When Nature Calls (1995) - Pontuação: 3.2857142857142856
# Item: Money Talks (1997) - Pontuação: 3.2834361177209908
# Item: Deceiver (1997) - Pontuação: 3.2504802625271947
# Item: Raise the Red Lantern (1991) - Pontuação: 3.25
# Item: Phantom, The (1996) - Pontuação: 3.25
# Item: Persuasion (1995) - Pontuação: 3.25
# Item: For Richer or Poorer (1997) - Pontuação: 3.25
# Item: Paris Was a Woman (1995) - Pontuação: 3.2448906492213414
# Item: Crying Game, The (1992) - Pontuação: 3.2425280990790206
# Item: Faces (1968) - Pontuação: 3.238101600066436
# Item: Bullets Over Broadway (1994) - Pontuação: 3.2265409196609864
# Item: Nosferatu a Venezia (1986) - Pontuação: 3.22423409327587
# Item: U.S. Marshalls (1998) - Pontuação: 3.2151363071004777
# Item: Don Juan DeMarco (1995) - Pontuação: 3.2
# Item: Harriet the Spy (1996) - Pontuação: 3.1818181818181817
# Item: Fools Rush In (1997) - Pontuação: 3.1739130434782608
# Item: Third Man, The (1949) - Pontuação: 3.170820393249937
# Item: Stephen King's The Langoliers (1995) - Pontuação: 3.154700538379252
# Item: Father of the Bride (1950) - Pontuação: 3.154700538379252
# Item: Year of the Horse (1997) - Pontuação: 3.125
# Item: Ma vie en rose (My Life in Pink) (1997) - Pontuação: 3.125
# Item: In the Bleak Midwinter (1995) - Pontuação: 3.111111111111111
# Item: Hearts and Minds (1996) - Pontuação: 3.111111111111111
# Item: Postman, The (1997) - Pontuação: 3.090909090909091
# Item: Boomerang (1992) - Pontuação: 3.0558674981356373
# Item: Junior (1994) - Pontuação: 3.0518838894346567
# Item: Wild Bunch, The (1969) - Pontuação: 3.0
# Item: White Squall (1996) - Pontuação: 3.0
# Item: Volcano (1997) - Pontuação: 3.0
# Item: Three Wishes (1995) - Pontuação: 3.0
# Item: That Darn Cat! (1997) - Pontuação: 3.0
# Item: Tango Lesson, The (1997) - Pontuação: 3.0
# Item: Some Like It Hot (1959) - Pontuação: 3.0
# Item: Smoke (1995) - Pontuação: 3.0
# Item: Sirens (1994) - Pontuação: 3.0
# Item: Seven Years in Tibet (1997) - Pontuação: 3.0
# Item: Rosencrantz and Guildenstern Are Dead (1990) - Pontuação: 3.0
# Item: Pump Up the Volume (1990) - Pontuação: 3.0
# Item: Ponette (1996) - Pontuação: 3.0
# Item: Poetic Justice (1993) - Pontuação: 3.0
# Item: Oscar & Lucinda (1997) - Pontuação: 3.0
# Item: My Life as a Dog (Mitt liv som hund) (1985) - Pontuação: 3.0
# Item: Mr. Magoo (1997) - Pontuação: 3.0
# Item: Money Talks (1997) - Pontuação: 3.0
# Item: Loch Ness (1995) - Pontuação: 3.0
# Item: Like Water For Chocolate (Como agua para chocolate) (1992) - Pontuação: 3.0
# Item: Life Less Ordinary, A (1997) - Pontuação: 3.0
# Item: Last Supper, The (1995) - Pontuação: 3.0
# Item: Halloween: The Curse of Michael Myers (1995) - Pontuação: 3.0
# Item: Half Baked (1998) - Pontuação: 3.0
# Item: Garden of Finzi-Contini, The (Giardino dei Finzi-Contini, Il) (1970) - Pontuação: 3.0
# Item: Frisk (1995) - Pontuação: 3.0
# Item: Fly Away Home (1996) - Pontuação: 3.0
# Item: Career Girls (1997) - Pontuação: 3.0
# Item: Candyman (1992) - Pontuação: 3.0
# Item: Body Snatchers (1993) - Pontuação: 3.0
# Item: Bananas (1971) - Pontuação: 3.0
# Item: Alaska (1996) - Pontuação: 3.0
# Item: Executive Decision (1996) - Pontuação: 2.925346869831102
# Item: Congo (1995) - Pontuação: 2.901408450704226
# Item: Once Upon a Time in America (1984) - Pontuação: 2.9009527756397326
# Item: Peacemaker, The (1997) - Pontuação: 2.8333333333333335
# Item: Bogus (1996) - Pontuação: 2.8333333333333335
# Item: Bent (1997) - Pontuação: 2.8333333333333335
# Item: April Fool's Day (1986) - Pontuação: 2.8264929921083266
# Item: Twilight (1998) - Pontuação: 2.8
# Item: Last Man Standing (1996) - Pontuação: 2.8
# Item: Boys Life (1995) - Pontuação: 2.7142857142857144
# Item: She's So Lovely (1997) - Pontuação: 2.6666666666666665
# Item: Perfect Candidate, A (1996) - Pontuação: 2.6666666666666665
# Item: Boxing Helena (1993) - Pontuação: 2.6666666666666665
# Item: Afterglow (1997) - Pontuação: 2.6
# Item: Fog, The (1980) - Pontuação: 2.585786437626905
# Item: American President, The (1995) - Pontuação: 2.5714285714285716
# Item: Singin' in the Rain (1952) - Pontuação: 2.5
# Item: Perez Family, The (1995) - Pontuação: 2.5
# Item: Mortal Kombat: Annihilation (1997) - Pontuação: 2.5
# Item: Lost Horizon (1937) - Pontuação: 2.5
# Item: Flubber (1997) - Pontuação: 2.5
# Item: Corrina, Corrina (1994) - Pontuação: 2.5
# Item: In the Mouth of Madness (1995) - Pontuação: 2.4285714285714284
# Item: James and the Giant Peach (1996) - Pontuação: 2.4
# Item: Demolition Man (1993) - Pontuação: 2.364611429231633
# Item: Strictly Ballroom (1992) - Pontuação: 2.0
# Item: Queen Margot (Reine Margot, La) (1994) - Pontuação: 2.0
# Item: Prophecy, The (1995) - Pontuação: 2.0
# Item: Pretty Woman (1990) - Pontuação: 2.0
# Item: Preacher's Wife, The (1996) - Pontuação: 2.0
# Item: Looking for Richard (1996) - Pontuação: 2.0
# Item: Killing Zoe (1994) - Pontuação: 2.0
# Item: Home Alone 3 (1997) - Pontuação: 2.0
# Item: Hard Target (1993) - Pontuação: 2.0
# Item: Drop Zone (1994) - Pontuação: 2.0
# Item: Police Story 4: Project S (Chao ji ji hua) (1993) - Pontuação: 1.9230769230769231
# Item: Tales from the Hood (1995) - Pontuação: 1.8345763534089954
# Item: Arsenic and Old Lace (1944) - Pontuação: 1.5
# Item: Tombstone (1993) - Pontuação: 1.0
# Item: Ruling Class, The (1972) - Pontuação: 1.0
# Item: Restoration (1995) - Pontuação: 1.0
# Item: Real Genius (1985) - Pontuação: 1.0
# Item: Heavy (1995) - Pontuação: 1.0
# Item: Courage Under Fire (1996) - Pontuação: 1.0
# Item: Castle Freak (1995) - Pontuação: 1.0
# Item: Casper (1995) - Pontuação: 1.0
# Item: Apartment, The (1960) - Pontuação: 1.0
